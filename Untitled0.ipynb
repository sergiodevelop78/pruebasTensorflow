# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiodevelop78/pruebasTensorflow/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!%tensorflow_version 2.x
# %cd /content
# !pip install Cython
# !pip install contextlib2 pillow lxml matplotlib PyDrive
# !pip install pycocotools
# !apt install protobuf-compiler python-pil python-lxml python-tk

# %%
#!git clone https://github.com/tensorflow/models.git 
#%cd ~/models/research
# %cd /content/models/
#!ls

# !protoc object_detection/protos/*.proto --python_out=.
# !export PYTHONPATH=$PYTHONPATH:`pwd`/slim
#!python object_detection/builders/model_builder_test.py

# %cd /content/models/research
# !protoc object_detection/protos/*.proto --python_out=.

import os
os.environ['PYTHONPATH']+=':/content/models/research/:/content/models/research/slim/'
# Out:
# /content/models
# annotations  label_map.pbtxt	  official			tf_record
# checkpoints  object_detection	  research			train
# eval	     object_train.record  ssd_mobilenet_v2_coco.config	trainval.txt
# images	     object_val.record	  temp
# /content/models/research

# %%
# %tensorflow_version 1.x
# %cd /content/models/

# !protoc object_detection/protos/*.proto --python_out=.
# %cd /content/models/research/
# !export PYTHONPATH=$PYTHONPATH:`pwd`/slim
# !python3 object_detection/builders/model_builder_test.py
# %cd /content/models/research/
# !protoc object_detection/protos/*.proto --python_out=.

import os
os.environ['PYTHONPATH']+=':/content/models/research/:/content/models/research/slim/'
# Out:
# /content/models
# /content/models/research
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Running tests under Python 3.6.9: /usr/bin/python3
# [ RUN      ] ModelBuilderTest.test_create_experimental_model
# [       OK ] ModelBuilderTest.test_create_experimental_model
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# ...

# %%
#%cd /content/
#!ls
#!cp drive/My\ Drive/models.zip /content
#!unzip models.zip
# %cd /content/models
#!ls


# !python3 object_detection/model_main.py --pipeline_config_path=ssd_mobilenet_v2_coco.config \
-num_train_steps=1000 --model_dir=train/ \
 --alsologtostderr
# Out:
# /content/models
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From object_detection/model_main.py:109: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/models/research/object_detection/utils/config_util.py:102: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0321 05:16:24.779609 139763131844480 module_wrapper.py:139] From /content/models/research/object_detection/utils/config_util.py:102: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
#!cat ssd_mobilenet_v2_coco.config
# !ls -lh /content/models 
# !ls -lh train/

# !date
# Out:
# total 60M
# drwxr-xr-x  2 root root  16K Mar 21 00:43 annotations
# drwxr-xr-x  2 root root 4.0K Mar 21 00:50 checkpoints
# drwxr-xr-x  2 root root 4.0K Mar 21 00:54 eval
# drwxr-xr-x  2 root root  12K Mar 21 00:43 images
# -rwxrwxr-x  1 root root   39 Mar 20 22:12 label_map.pbtxt
# drwxr-xr-x 26 root root 4.0K Mar 21 00:06 object_detection
# -rw-r--r--  1 root root  44M Mar 21 00:45 object_train.record
# -rw-r--r--  1 root root  17M Mar 21 00:45 object_val.record
# drwxr-xr-x 11 root root 4.0K Mar 20 23:27 official
# drwxr-xr-x 63 root root 4.0K Mar 20 23:27 research
# -rw-r--r--  1 root root 4.5K Mar 21 00:53 ssd_mobilenet_v2_coco.config
# drwxr-xr-x  3 root root 4.0K Mar 20 23:41 temp
# drwxr-xr-x  2 root root 4.0K Mar 21 00:45 tf_record
# drwxr-xr-x  2 root root 4.0K Mar 21 04:51 train
# -rw-r--r--  1 root root 2.5K Mar 21 00:04 trainval.txt
# total 0
# Sat Mar 21 05:04:21 UTC 2020
